# %%
 # Cell 2: Import libraries
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
import pandas as pd
import os
from IPython.display import display, Markdown

# %%
# Cell 3: Check model directory
model_path = "../models/crop_recommendation_no_lora"

print("📁 Checking model directory...")
if os.path.exists(model_path):
    print(f"✅ Model directory found: {model_path}")
    files = os.listdir(model_path)
    print("📄 Model files:")
    for file in files:
        print(f"   - {file}")
else:
    print(f"❌ Model directory not found: {model_path}")
    print("Please check if your model finished training successfully.")
